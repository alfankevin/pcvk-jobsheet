# %% [markdown]
# <a href="https://colab.research.google.com/github/alfankevin/praktikum-vision/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alfan Farchi Al-Hadi | 2141720084 | 3A | 07

# %% [markdown]
# # MODUL 12 – Feature Matching, Face Detection, Face Tracking

# %% [markdown]
# 1. Import beberapa library dan akses folder yang ada di Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# 2. Lakukan Face Detection untuk image object lain yang tersedia pada (/images/facedet).

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/faces/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/faces/jokowi.jpg')
jokowi_rgb = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)
roi_wajah = cascade_wajah.detectMultiScale(jokowi)
plt.subplot(1, 2, 1)
plt.imshow(jokowi_rgb)
plt.axis('off')

jokowi_detected = jokowi_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(jokowi_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(jokowi_detected)
plt.axis('off')

plt.show()


kartini = cv.imread('/content/drive/MyDrive/faces/kartini.jpg')
kartini_rgb = cv.cvtColor(kartini, cv.COLOR_BGR2RGB)
roi_wajah = cascade_wajah.detectMultiScale(kartini)
plt.subplot(1, 2, 1)
plt.imshow(kartini_rgb)
plt.axis('off')

kartini_detected = kartini_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(kartini_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(kartini_detected)
plt.axis('off')

plt.show()


mycat = cv.imread('/content/drive/MyDrive/faces/mycat.jpg')
mycat_rgb = cv.cvtColor(mycat, cv.COLOR_BGR2RGB)
roi_wajah = cascade_wajah.detectMultiScale(mycat)
plt.subplot(1, 2, 1)
plt.imshow(mycat_rgb)
plt.axis('off')

mycat_detected = mycat_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(mycat_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(mycat_detected)
plt.axis('off')

plt.show()


mask = cv.imread('/content/drive/MyDrive/faces/mask.png')
mask_rgb = cv.cvtColor(mask, cv.COLOR_BGR2RGB)
roi_wajah = cascade_wajah.detectMultiScale(mask)
plt.subplot(1, 2, 1)
plt.imshow(mask_rgb)
plt.axis('off')

mask_detected = mask_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(mask_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(mask_detected)
plt.axis('off')

plt.show()


mjordan = cv.imread('/content/drive/MyDrive/faces/mjordan.jpg')
mjordan_rgb = cv.cvtColor(mjordan, cv.COLOR_BGR2RGB)
roi_wajah = cascade_wajah.detectMultiScale(mjordan)
plt.subplot(1, 2, 1)
plt.imshow(mjordan_rgb)
plt.axis('off')

mjordan_detected = mjordan_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(mjordan_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(mjordan_detected)
plt.axis('off')

plt.show()


solvayconf = cv.imread('/content/drive/MyDrive/faces/solvayconf.jpg')
solvayconf_rgb = cv.cvtColor(solvayconf, cv.COLOR_BGR2RGB)
roi_wajah = cascade_wajah.detectMultiScale(solvayconf)
plt.subplot(1, 2, 1)
plt.imshow(solvayconf_rgb)
plt.axis('off')

solvayconf_detected = solvayconf_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(solvayconf_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(solvayconf_detected)
plt.axis('off')

plt.show()

# %% [markdown]
# 3. Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah
# kucing hingga muncul rectangle pada bagian wajahnya. Petunjuk pada soal ini,
# perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang ada
# jika memang telah disediakan. Jika belum ada, coba cari dengan searching melalui
# search engines.

# %%
cascade_cat = cv.CascadeClassifier('/content/drive/MyDrive/faces/haarcascade_frontalcatface.xml')

mycat = cv.imread('/content/drive/MyDrive/faces/mycat.jpg')
mycat_rgb = cv.cvtColor(mycat, cv.COLOR_BGR2RGB)
roi_wajah = cascade_cat.detectMultiScale(mycat)
plt.subplot(1, 2, 1)
plt.imshow(mycat_rgb)
plt.axis('off')

mycat_detected = mycat_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(mycat_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(mycat_detected)
plt.axis('off')

plt.show()


kucing = cv.imread('/content/drive/MyDrive/faces/kucing2.jpg')
kucing_rgb = cv.cvtColor(kucing, cv.COLOR_BGR2RGB)
roi_wajah = cascade_cat.detectMultiScale(kucing)
plt.subplot(1, 2, 1)
plt.imshow(kucing_rgb)
plt.axis('off')

kucing_detected = kucing_rgb.copy()
for (x, y, w, h) in roi_wajah:
    cv.rectangle(kucing_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(kucing_detected)
plt.axis('off')

plt.show()

# %% [markdown]
# 4. Cobakan juga untuk eyes detection.

# %%
cascade_eye = cv.CascadeClassifier('/content/drive/MyDrive/faces/haarcascade_eye.xml')

jokowi = cv.imread('/content/drive/MyDrive/faces/jokowi.jpg')
jokowi_rgb = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)
roi_mata = cascade_eye.detectMultiScale(jokowi)
plt.subplot(1, 2, 1)
plt.imshow(jokowi_rgb)
plt.axis('off')

jokowi_detected = jokowi_rgb.copy()
for (x, y, w, h) in roi_mata:
    cv.rectangle(jokowi_detected, (x, y), (x+w, y+h), (0, 255, 0), 3)
plt.subplot(1, 2, 2)
plt.imshow(jokowi_detected)
plt.axis('off')

plt.show()

# %% [markdown]
# 5. Lakukan Face Tracking menggunakan Google Colab.

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Load the pre-trained face cascade
cascade_wajah = cv.CascadeClassifier(cv.data.haarcascades + 'haarcascade_frontalface_alt.xml')

# Open a video capture object (0 corresponds to the default camera)
cap = cv.VideoCapture(0)  # Use cv.VideoCapture('your_video_file.mp4') for a video file

while True:
    # Read a frame from the video capture
    ret, frame = cap.read()

    if not ret:
        break  # Break the loop if the video capture fails

    # Convert the frame to grayscale for face detection
    gray_frame = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

    # Detect faces in the frame
    roi_wajah = cascade_wajah.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Draw rectangles around the detected faces
    for (x, y, w, h) in roi_wajah:
        cv.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 3)

    # Display the frame with face tracking
    cv.imshow('Face Tracking', frame)

    # Break the loop if the 'q' key is pressed
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close all windows
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# 6. Lakukan Blurring pada bagian wajah yang terdeteksi.

# %%
mjordan = cv.imread('/content/drive/MyDrive/faces/mjordan.jpg')

mjordan_rgb = cv.cvtColor(mjordan, cv.COLOR_BGR2RGB)
mjordan_blur = mjordan_rgb.copy()
roi_wajah = cascade_wajah.detectMultiScale(mjordan_rgb)

for (x, y, w, h) in roi_wajah:
    roi = mjordan_blur[y:y+h, x:x+w]
    roi = cv.medianBlur(roi, 15)
    mjordan_blur[y:y+h, x:x+w] = roi

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(mjordan_rgb)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(mjordan_blur)
plt.axis('off')

plt.show()

# %% [markdown]
# 7. Lakukan segmentasi karakter pada KTP.

# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# !pip install pillow
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 6 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (7,938 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract

ktp = cv.imread('/content/drive/MyDrive/ktp/ktp2.jpg')

gray_image = cv2.cvtColor(ktp, cv2.COLOR_BGR2GRAY)

_, threshold_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)

detected_text = pytesseract.image_to_string(threshold_image)
print("Detected Text:\n", detected_text)

plt.imshow(threshold_image, cmap='gray')
plt.title('Detected Text')
plt.axis('off')
plt.show()
# Out:
# Detected Text:
#  PROV INSI JAWA BARAT
# KOTA CIMAHI
#
# 321706 1804870007
#
# PABIEF WIJAYA PUTRA
# BANDUNG, 18-04-1987
#
#
#
#
#
# Status Perkawinarn: BELUM KAWIN . - KOTA CIMAHI
# Pekerjean : PELAJARIMAHASISWA - 17-41-2015
# Kewargenegaraan: WNI : At
# Berlaku Hingga : SEUMUR HIDUP
